# %% [markdown]
# !pip install basemap
# !pip install basemap-data

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(projection='ortho', lat_0=50, lon_0=-100, resolution='l', area_thresh=1000.0)
map.drawcoastlines()
plt.show()

# %%
from mpl_toolkits.basemap import Basemap

fig = plt.figure(figsize=(15, 15))
m = Basemap(#projection='gall',
            llcrnrlat=-90,urcrnrlat=90,\
            llcrnrlon=-180,urcrnrlon=180,resolution='c')
#m.shadedrelief()
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
m.drawmapboundary(fill_color='aqua')
m.drawcountries( linewidth =0.5 , linestyle='solid' , color='k' , antialiased=1 , ax=None , zorder=None )

plt.title("Gall Stereographic Projection")
plt.show()


#m=sns.heatmap(data=data, cmap='YlOrRd', annot=True)

#fig.write_html('/home/tio/IDE/project_0.5/figure/9.1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 16
#      13 plt.title("Gall Stereographic Projection")
#      14 plt.show()
# ---> 16 data = churn_data.groupby('Geography', as_index=False)['Exited'].mean().round(2)
#      17 display(data)
#
# NameError: name 'churn_data' is not defined
